# %%
print ('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# #Comments

# %%
list = [1,2,3,4,5]

# %%
type(list)
# Out:
# list

# %%
dict_info= {'name' : 'Frank', 'Age':'19'}

# %%
type(dict_info)
# Out:
# dict

# %%
def square_num():
    print('Hello World!')

# %%
square_num()
# Out:
# Hello World!

# %%
def sqaures(num):
    print (num**2)

# %%
sqaures(3)
# Out:
# 9

# %%
def pent(*nums):
    print(nums[0]*nums[1])

# %%
pent(1,2,3,4)
# Out:
# 2

# %%
def oct(nu,pu):
    print(nu ** pu)

# %%
print(2,3)
# Out:
# 2 3

# %%
oct(2,3)
# Out:
# 8

# %%
oct(pu=3, nu=2)
# Out:
# 8
