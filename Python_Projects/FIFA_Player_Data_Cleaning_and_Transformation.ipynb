# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/olatundeolasunkanmi/Downloads/archive (3).zip_1/fifa21_raw_data.csv', low_memory = False)

# %%
df
# Out:
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# 2      https://cdn.sofifa.com/players/200/389/21_60.png
# 3      https://cdn.sofifa.com/players/192/985/21_60.png
# 4      https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                 ...
# 18974  https://cdn.sofifa.com/players/257/710/21_60.png
# 18975  https://cdn.sofifa.com/players/258/736/21_60.png
# 18976  https://cdn.sofifa.com/players/247/223/21_60.png
# 18977  https://cdn.sofifa.com/players/258/760/21_60.png
# 18978  https://cdn.sofifa.com/players/255/958/21_60.png
#
#                            LongName  \
# 0                      Lionel Messi
# 1      C. Ronaldo dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar da Silva Santos Jr.
# ...                             ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 77 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   photoUrl          18979 non-null  object
#  1   LongName          18979 non-null  object
#  2   playerUrl         18979 non-null  object
#  3   Nationality       18979 non-null  object
#  4   Positions         18979 non-null  object
#  5   Name              18979 non-null  object
#  6   Age               18979 non-null  int64
#  7   ↓OVA              18979 non-null  int64
#  8   POT               18979 non-null  int64
#  9   Team & Contract   18979 non-null  object
#  10  ID                18979 non-null  int64
#  11  Height            18979 non-null  object
#  12  Weight            18979 non-null  object
#  13  foot              18979 non-null  object
#  14  BOV               18979 non-null  int64
#  15  BP                18979 non-null  object
# ...

# %%
pd.set_option('display.max_columns', None)
df.tail(10)
# Out:
#              LongName Nationality Positions            Name  Age  ↓OVA  POT  \
# 18969      Jiyu Zhong    China PR        CM      Zhong Jiyu   23    47   55
# 18970   Wenzhuo Huang    China PR        CM   Huang Wenzhou   21    47   53
# 18971        Yue Song    China PR        CM        Song Yue   28    47   47
# 18972    Huapeng Wang    China PR        CB    Wang Huapeng   20    47   53
# 18973     Zitong Chen    China PR        CM     Chen Zitong   23    47   51
# 18974  Mengxuan Zhang    China PR        CB  Zhang Mengxuan   21    47   52
# 18975   Vani Da Silva     England        ST     V. Da Silva   17    47   67
# 18976          Ao Xia    China PR        CB          Xia Ao   21    47   55
# 18977       Ben Hough     England        CM        B. Hough   17    47   67
# 18978    Mateo Flores     Bolivia       CDM       M. Flores   19    47   63
#
#                                          Team & Contract      ID Height  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 75 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LongName          18979 non-null  object
#  1   Nationality       18979 non-null  object
#  2   Positions         18979 non-null  object
#  3   Name              18979 non-null  object
#  4   Age               18979 non-null  int64
#  5   ↓OVA              18979 non-null  int64
#  6   POT               18979 non-null  int64
#  7   Team & Contract   18979 non-null  object
#  8   ID                18979 non-null  int64
#  9   Height            18979 non-null  object
#  10  Weight            18979 non-null  object
#  11  foot              18979 non-null  object
#  12  BOV               18979 non-null  int64
#  13  BP                18979 non-null  object
#  14  Growth            18979 non-null  int64
#  15  Joined            18979 non-null  object
# ...

# %%
df.describe()
# Out:
#                 Age          ↓OVA           POT             ID           BOV  \
# count  18979.000000  18979.000000  18979.000000   18979.000000  18979.000000
# mean      25.194583     65.718636     71.136098  226404.790242     66.751620
# std        4.710753      6.968999      6.114176   27141.673349      6.747017
# min       16.000000     47.000000     47.000000      41.000000     48.000000
# 25%       21.000000     61.000000     67.000000  210135.000000     62.000000
# 50%       25.000000     66.000000     71.000000  232424.000000     67.000000
# 75%       29.000000     70.000000     75.000000  246925.500000     71.000000
# max       53.000000     93.000000     95.000000  259216.000000     93.000000
#
#              Growth     Attacking      Crossing     Finishing  \
# count  18979.000000  18979.000000  18979.000000  18979.000000
# mean       5.417461    248.938616     49.688551     45.842932
# std        5.663954     74.299764     18.131334     19.566978
# ...

# %%
pd.set_option('display.max_rows', None)
df.isna().sum()
# Out:
# LongName                0
# Nationality             0
# Positions               0
# Name                    0
# Age                     0
# ↓OVA                    0
# POT                     0
# Team & Contract         0
# ID                      0
# Height                  0
# Weight                  0
# foot                    0
# BOV                     0
# BP                      0
# Growth                  0
# Joined                  0
# Loan Date End       17966
# Value                   0
# Wage                    0
# Release Clause          0
# Attacking               0
# Crossing                0
# Finishing               0
# Heading Accuracy        0
# Short Passing           0
# Volleys                 0
# Skill                   0
# Dribbling               0
# Curve                   0
# FK Accuracy             0
# Long Passing            0
# Ball Control            0
# Movement                0
# Acceleration            0
# Sprint Speed            0
# ...

# %%
df['is_on_loan'] = df['Loan Date End'].notna().astype(int)

# %%
print(df)
# Out:
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# 2      https://cdn.sofifa.com/players/200/389/21_60.png
# 3      https://cdn.sofifa.com/players/192/985/21_60.png
# 4      https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                 ...
# 18974  https://cdn.sofifa.com/players/257/710/21_60.png
# 18975  https://cdn.sofifa.com/players/258/736/21_60.png
# 18976  https://cdn.sofifa.com/players/247/223/21_60.png
# 18977  https://cdn.sofifa.com/players/258/760/21_60.png
# 18978  https://cdn.sofifa.com/players/255/958/21_60.png
#
#                            LongName  \
# 0                      Lionel Messi
# 1      C. Ronaldo dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar da Silva Santos Jr.
# ...                             ...
# ...

# %%
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')

# %%
df
# Out:
#                            LongName Nationality Positions               Name  \
# 0                      Lionel Messi   Argentina  RW ST CF           L. Messi
# 1      C. Ronaldo dos Santos Aveiro    Portugal     ST LW  Cristiano Ronaldo
# 2                         Jan Oblak    Slovenia        GK           J. Oblak
# 3                   Kevin De Bruyne     Belgium    CAM CM       K. De Bruyne
# 4        Neymar da Silva Santos Jr.      Brazil    LW CAM          Neymar Jr
# ...                             ...         ...       ...                ...
# 18974                Mengxuan Zhang    China PR        CB     Zhang Mengxuan
# 18975                 Vani Da Silva     England        ST        V. Da Silva
# 18976                        Ao Xia    China PR        CB             Xia Ao
# 18977                     Ben Hough     England        CM           B. Hough
# 18978                  Mateo Flores     Bolivia       CDM          M. Flores
#
# ...

# %%
del df['is_permanent']

# %%
df
# Out:
#                            LongName Nationality Positions               Name  \
# 0                      Lionel Messi   Argentina  RW ST CF           L. Messi
# 1      C. Ronaldo dos Santos Aveiro    Portugal     ST LW  Cristiano Ronaldo
# 2                         Jan Oblak    Slovenia        GK           J. Oblak
# 3                   Kevin De Bruyne     Belgium    CAM CM       K. De Bruyne
# 4        Neymar da Silva Santos Jr.      Brazil    LW CAM          Neymar Jr
# ...                             ...         ...       ...                ...
# 18974                Mengxuan Zhang    China PR        CB     Zhang Mengxuan
# 18975                 Vani Da Silva     England        ST        V. Da Silva
# 18976                        Ao Xia    China PR        CB             Xia Ao
# 18977                     Ben Hough     England        CM           B. Hough
# 18978                  Mateo Flores     Bolivia       CDM          M. Flores
#
# ...

# %%
del df['Loan Date End']

# %%
df
# Out:
#                            LongName Nationality Positions               Name  \
# 0                      Lionel Messi   Argentina  RW ST CF           L. Messi
# 1      C. Ronaldo dos Santos Aveiro    Portugal     ST LW  Cristiano Ronaldo
# 2                         Jan Oblak    Slovenia        GK           J. Oblak
# 3                   Kevin De Bruyne     Belgium    CAM CM       K. De Bruyne
# 4        Neymar da Silva Santos Jr.      Brazil    LW CAM          Neymar Jr
# ...                             ...         ...       ...                ...
# 18974                Mengxuan Zhang    China PR        CB     Zhang Mengxuan
# 18975                 Vani Da Silva     England        ST        V. Da Silva
# 18976                        Ao Xia    China PR        CB             Xia Ao
# 18977                     Ben Hough     England        CM           B. Hough
# 18978                  Mateo Flores     Bolivia       CDM          M. Flores
#
# ...

# %%
df.to_csv('/Users/olatundeolasunkanmi/Downloads/archive (3).zip_1/fifa_cleaned.csv')
